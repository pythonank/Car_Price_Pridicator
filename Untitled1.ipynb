# %%
import streamlit as st
import pandas as pd
import pickle
import os

# Function to load a file
def load_file(path, file_type="Pipeline/Model"):
    if os.path.exists(path):
        try:
            with open(path, 'rb') as file:
                return pickle.load(file)
        except Exception as e:
            st.error(f"Error loading {file_type}: {e}")
            return None
    else:
        st.error(f"{file_type} file not found: {path}")
        return None

# Paths to files
pipeline_path = r'C:\Users\ankit\Downloads\car_price_pipeline.pkl'
model_path = r'C:\Users\ankit\Downloads\car_price_model.pkl'
# Load files
pipeline = load_file(pipeline_path, "Pipeline")
model = load_file(model_path, "Model")

# Streamlit App
st.title("Car Price Prediction App")

# User inputs
car_age = st.number_input("Year of Manufacture", min_value=4, max_value=32, value=24)
km_driven = st.number_input("Kilometers Driven", min_value=0, value=25000)
fuel = st.selectbox("Fuel Type", ["Petrol", "Diesel", "CNG", "LPG"])
seller_type = st.selectbox("Seller Type", ["Dealer", "Individual"])
transmission = st.selectbox("Transmission Type", ["Manual", "Automatic"])
owner = st.selectbox("Owner Type", ["First Owner", "Second Owner", "Third Owner", "Fourth & Above Owner", "Test Drive Car"])

# Predict button
if st.button("Predict Selling Price"):
    if pipeline and model:
        # Create DataFrame
        input_data = pd.DataFrame([[car_age, km_driven, fuel, seller_type, transmission, owner]],
                                  columns=['car_age', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner'])

        try:
            # Predict
            prediction = pipeline.predict(input_data)
            st.success(f"Predicted Selling Price: ₹{prediction[0]:,.2f}")
        except Exception as e:
            st.error(f"Error during prediction: {e}")
    else:
        st.error("Files not loaded correctly. Check paths and try again.")
# Out:
# 2024-12-03 15:26:01.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:01.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 15:26:02.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
